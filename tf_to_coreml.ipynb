# %% [markdown]
# ### Full conversion of TF model to CoreML
#
# This notebook provides a good example of how to work with tf -> coreml conversion aтв also how to test model after this conversion.

# %%
import tensorflow as tf
print("TF version:", tf.__version__)

import numpy as np
from matplotlib import pyplot as plt
import network
slim = tf.contrib.slim

import os
import argparse
import json
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TF version: 1.12.0

# %% [markdown]
# #### Load model from checkpoint

# %%
with open('train/data.json', 'r') as fp:
    args = json.load(fp)

class Dotdict(dict):
     """dot.notation access to dictionary attributes"""
     __getattr__ = dict.get
     __setattr__ = dict.__setitem__
     __delattr__ = dict.__delitem__

args = Dotdict(args)

# 0=background
# 1=aeroplane
# 2=bicycle
# 3=bird
# 4=boat
# 5=bottle
# 6=bus
# 7=car
# 8=cat
# 9=chair
# 10=cow
# 11=diningtable
# 12=dog
# 13=horse
# 14=motorbike
# 15=person
# 16=potted plant
# 17=sheep
# 18=sofa
# 19=train
# 20=tv/monitor
# 255=unknown

class_labels = [v for v in range((args.number_of_classes+1))]
class_labels[-1] = 255

# %%
args
# Out:
# {'accumulated_validation_miou': 0,
#  'batch_norm_decay': 0.997,
#  'batch_norm_epsilon': 1e-05,
#  'batch_size': 16,
#  'crop_size': 512,
#  'current_best_val_loss': '0.294389428197',
#  'gpu_id': 1,
#  'l2_regularizer': 0.0001,
#  'multi_grid': [1, 2, 4],
#  'number_of_classes': 21,
#  'output_stride': 16,
#  'resnet_model': 'resnet_v2_50',
#  'starting_learning_rate': 1e-05}

# %% [markdown]
# #### We want to upload image for testing and create dataset for this image. Could be usefull for the following inference.

# %%
# step 1
filenames = tf.constant(['test_image/4.jpg'])

# step 2: create a dataset returning slices of `filenames`
dataset = tf.data.Dataset.from_tensor_slices((filenames))

# step 3: parse every image in the dataset using `map`
def _parse_function(filename):
    image_string = tf.read_file(filename)
    image_decoded = tf.image.decode_jpeg(image_string, channels=3)
    image = tf.image.resize_images(image_decoded, size=[513, 513], 
                                   method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    image = tf.cast(image, tf.float32)
    return image

dataset = dataset.map(_parse_function)
dataset = dataset.batch(1)

# step 4: create iterator and final input tensor
iterator = dataset.make_one_shot_iterator()
batch_images_tf = iterator.get_next()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL

# %matplotlib inline

try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

jpeg_bin_tensor = batch_images_tf

with tf.Session() as sess:
    # display encoded back to image data
    jpeg_bin = sess.run(jpeg_bin_tensor)
    print(jpeg_bin.shape)
    plt.imshow(jpeg_bin[0])
# Out:
# (1, 513, 513, 3)

# %%
jpeg_bin.shape
# Out:
# (1, 513, 513, 3)

# %% [markdown]
# #### This function is for downloading resnet checkpoint

# %%
import urllib
import tarfile
import os

def download_resnet_checkpoint_if_necessary(resnet_checkpoints_path, resnet_model_name):
    """
    Check if the resnet checkpoints are already downloaded, if not download it
    :param resnet_checkpoints_path: string: path where the properly resnet checkpoint files should be found
    :param resnet_model_name: one of resnet_v2_50 or resnet_v2_101
    :return: None
    """
    if not os.path.exists(resnet_checkpoints_path):
        # create the path and download the resnet checkpoints
        os.mkdir(resnet_checkpoints_path)

        filename = resnet_model_name + "_2017_04_14.tar.gz"

        url = "http://download.tensorflow.org/models/" + filename
        full_file_path = os.path.join(resnet_checkpoints_path, filename)
        urllib.request.urlretrieve(url, full_file_path)
        thetarfile = tarfile.open(full_file_path, "r:gz")
        thetarfile.extractall(path=resnet_checkpoints_path)
        thetarfile.close()
        print("Resnet:", resnet_model_name, "successfully downloaded.")
    else:
        print("ResNet checkpoints file successfully found.")

# %%
download_resnet_checkpoint_if_necessary("resnet/checkpoints/", 'resnet_v2_50')
# Out:
# ResNet checkpoints file successfully found.

# %% [markdown]
# #### Here we are creating the graph for tensorflow model

# %%
batch_images = tf.placeholder(tf.float32, [None, 513, 513, 3])

# %%
logits_tf =  network.deeplab_v3(batch_images, 
                                args, 
                                is_training=False, reuse=tf.AUTO_REUSE)

predictions_tf = tf.argmax(logits_tf, axis=3)
probabilities_tf = tf.nn.softmax(logits_tf[0])

map_resized_back = tf.image.resize_images(probabilities_tf, [960, 768])

merged_summary_op = tf.summary.merge_all()
saver = tf.train.Saver()

test_folder = 'train'

# %% [markdown]
# #### Loading session and saving it

# %%
with tf.Session() as sess:

    # Create a saver.
    sess.run(tf.local_variables_initializer())
    sess.run(tf.global_variables_initializer())

    # Restore variables from disk.
    saver.restore(sess, os.path.join(test_folder, "model.ckpt"))
    print("Model restored.")
    
    probabilities_tf_np = sess.run([probabilities_tf], 
                                   feed_dict={batch_images: jpeg_bin})
    
    tf.train.write_graph(sess.graph, './', 'model.pbtxt')
# Out:
# INFO:tensorflow:Restoring parameters from train/model.ckpt
# Model restored.

# %% [markdown]
# #### Freezing session graph and saving it.

# %%
from tensorflow.python.tools.freeze_graph import freeze_graph

# Graph definition file, stored as protobuf TEXT
graph_def_file = './model.pbtxt'
# Trained model's checkpoint name
checkpoint_file = './train/model.ckpt'
# Frozen model's output name
frozen_model_file = './frozen_model.pb'
# Output nodes. If there're multiple output ops, use comma separated string, e.g. "out1,out2".
output_node_names = 'Softmax' 

# Call freeze graph
freeze_graph(input_graph=graph_def_file,
             input_saver="",
             input_binary=False,
             input_checkpoint=checkpoint_file,
             output_node_names=output_node_names,
             restore_op_name="save/restore_all",
             filename_tensor_name="save/Const:0",
             output_graph=frozen_model_file,
             clear_devices=True,
             initializer_nodes="")
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/tools/freeze_graph.py:249: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# INFO:tensorflow:Restoring parameters from ./train/model.ckpt
# INFO:tensorflow:Froze 298 variables.
# INFO:tensorflow:Converted 298 variables to const ops.

# %% [markdown]
# #### Here is the convertion from tf to coreml

# %%
import tfcoreml

"""
Step 2: Call converter
"""

# Provide these inputs in addition to inputs in Step 1
# A dictionary of input tensors' name and shape (with batch)
input_tensor_shapes = {"Placeholder:0":[1, 513, 513, 3]} # batch size is 1
# Output CoreML model path
coreml_model_file = 'model.mlmodel'
output_tensor_names = ['Softmax:0']


# Call the converter
coreml_model = tfcoreml.convert(
    tf_model_path=frozen_model_file, 
    mlmodel_path=coreml_model_file, 
    input_name_shape_dict=input_tensor_shapes,
    output_feature_names=output_tensor_names
)
# Out:
# Loading the TF graph...
# Graph Loaded.
# Collecting all the 'Const' ops from the graph, by running it....
# Done.
# Now finding ops in the TF graph that can be dropped for inference
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob Placeholder:0
# 1/870: Analysing op name: strided_slice/stack_2 ( type:  Const )
# 2/870: Analysing op name: strided_slice/stack_1 ( type:  Const )
# 3/870: Analysing op name: strided_slice/stack ( type:  Const )
# 4/870: Analysing op name: DeepLab_v3/strided_slice/stack_2 ( type:  Const )
# 5/870: Analysing op name: DeepLab_v3/strided_slice/stack_1 ( type:  Const )
# 6/870: Analysing op name: DeepLab_v3/strided_slice/stack ( type:  Const )
# 7/870: Analysing op name: DeepLab_v3/logits/biases ( type:  Const )
# 8/870: Analysing op name: DeepLab_v3/logits/biases/read ( type:  Identity )
# 9/870: Analysing op name: DeepLab_v3/logits/weights ( type:  Const )
# 10/870: Analysing op name: DeepLab_v3/logits/weights/read ( type:  Identity )
# 11/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/moving_variance ( type:  Const )
# 12/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/moving_variance/read ( type:  Identity )
# 13/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/moving_mean ( type:  Const )
# 14/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/moving_mean/read ( type:  Identity )
# 15/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/gamma ( type:  Const )
# 16/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/gamma/read ( type:  Identity )
# 17/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/beta ( type:  Const )
# 18/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/beta/read ( type:  Identity )
# 19/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/weights ( type:  Const )
# 20/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/weights/read ( type:  Identity )
# 21/870: Analysing op name: DeepLab_v3/ASPP_layer/concat/axis ( type:  Const )
# 22/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/moving_variance ( type:  Const )
# 23/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/moving_variance/read ( type:  Identity )
# 24/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/moving_mean ( type:  Const )
# 25/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/moving_mean/read ( type:  Identity )
# 26/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/gamma ( type:  Const )
# 27/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/gamma/read ( type:  Identity )
# 28/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/beta ( type:  Const )
# 29/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/beta/read ( type:  Identity )
# 30/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchToSpaceND/crops ( type:  Const )
# 31/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchToSpaceND/block_shape ( type:  Const )
# 32/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/SpaceToBatchND/paddings ( type:  Const )
# 33/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/SpaceToBatchND/block_shape ( type:  Const )
# 34/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/weights ( type:  Const )
# 35/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/weights/read ( type:  Identity )
# 36/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/moving_variance ( type:  Const )
# 37/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/moving_variance/read ( type:  Identity )
# 38/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/moving_mean ( type:  Const )
# 39/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/moving_mean/read ( type:  Identity )
# 40/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/gamma ( type:  Const )
# 41/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/gamma/read ( type:  Identity )
# 42/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/beta ( type:  Const )
# 43/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/beta/read ( type:  Identity )
# 44/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchToSpaceND/crops ( type:  Const )
# 45/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchToSpaceND/block_shape ( type:  Const )
# 46/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/SpaceToBatchND/paddings ( type:  Const )
# 47/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/SpaceToBatchND/block_shape ( type:  Const )
# 48/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/weights ( type:  Const )
# 49/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/weights/read ( type:  Identity )
# 50/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/moving_variance ( type:  Const )
# 51/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/moving_variance/read ( type:  Identity )
# 52/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/moving_mean ( type:  Const )
# 53/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/moving_mean/read ( type:  Identity )
# 54/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/gamma ( type:  Const )
# 55/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/gamma/read ( type:  Identity )
# 56/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/beta ( type:  Const )
# 57/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/beta/read ( type:  Identity )
# 58/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchToSpaceND/crops ( type:  Const )
# 59/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchToSpaceND/block_shape ( type:  Const )
# 60/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/SpaceToBatchND/paddings ( type:  Const )
# 61/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/SpaceToBatchND/block_shape ( type:  Const )
# 62/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/weights ( type:  Const )
# 63/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/weights/read ( type:  Identity )
# 64/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/moving_variance ( type:  Const )
# 65/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/moving_variance/read ( type:  Identity )
# 66/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/moving_mean ( type:  Const )
# 67/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/moving_mean/read ( type:  Identity )
# 68/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/gamma ( type:  Const )
# 69/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/gamma/read ( type:  Identity )
# 70/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/beta ( type:  Const )
# 71/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/beta/read ( type:  Identity )
# 72/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/weights ( type:  Const )
# 73/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/weights/read ( type:  Identity )
# 74/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice_1/stack_2 ( type:  Const )
# 75/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice_1/stack_1 ( type:  Const )
# 76/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice_1/stack ( type:  Const )
# 77/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice/stack_2 ( type:  Const )
# 78/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice/stack_1 ( type:  Const )
# 79/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice/stack ( type:  Const )
# 80/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/moving_variance ( type:  Const )
# 81/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/moving_variance/read ( type:  Identity )
# 82/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/moving_mean ( type:  Const )
# 83/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/moving_mean/read ( type:  Identity )
# 84/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/gamma ( type:  Const )
# 85/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/gamma/read ( type:  Identity )
# 86/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/beta ( type:  Const )
# 87/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/beta/read ( type:  Identity )
# 88/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/weights ( type:  Const )
# 89/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/weights/read ( type:  Identity )
# 90/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_global_pool/reduction_indices ( type:  Const )
# 91/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv3/biases ( type:  Const )
# 92/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 93/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv3/weights ( type:  Const )
# 94/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 95/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 96/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 97/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 98/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 99/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 100/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 101/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 102/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 103/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchToSpaceND/crops ( type:  Const )
# 104/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchToSpaceND/block_shape ( type:  Const )
# 105/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/SpaceToBatchND/paddings ( type:  Const )
# 106/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/SpaceToBatchND/block_shape ( type:  Const )
# 107/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/weights ( type:  Const )
# 108/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 109/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 110/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 111/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 112/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 113/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 114/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 115/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 116/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 117/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/weights ( type:  Const )
# 118/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 119/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/moving_variance ( type:  Const )
# 120/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 121/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/moving_mean ( type:  Const )
# 122/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 123/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/gamma ( type:  Const )
# 124/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 125/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/beta ( type:  Const )
# 126/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/beta/read ( type:  Identity )
# 127/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv3/biases ( type:  Const )
# 128/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 129/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv3/weights ( type:  Const )
# 130/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 131/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 132/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 133/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 134/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 135/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 136/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 137/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 138/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 139/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchToSpaceND/crops ( type:  Const )
# 140/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchToSpaceND/block_shape ( type:  Const )
# 141/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/SpaceToBatchND/paddings ( type:  Const )
# 142/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/SpaceToBatchND/block_shape ( type:  Const )
# 143/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/weights ( type:  Const )
# 144/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 145/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 146/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 147/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 148/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 149/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 150/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 151/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 152/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 153/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/weights ( type:  Const )
# 154/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 155/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/moving_variance ( type:  Const )
# 156/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 157/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/moving_mean ( type:  Const )
# 158/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 159/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/gamma ( type:  Const )
# 160/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 161/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/beta ( type:  Const )
# 162/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/beta/read ( type:  Identity )
# 163/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv3/biases ( type:  Const )
# 164/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 165/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv3/weights ( type:  Const )
# 166/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 167/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 168/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 169/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 170/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 171/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 172/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 173/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 174/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 175/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchToSpaceND/crops ( type:  Const )
# 176/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchToSpaceND/block_shape ( type:  Const )
# 177/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/SpaceToBatchND/paddings ( type:  Const )
# 178/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/SpaceToBatchND/block_shape ( type:  Const )
# 179/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/weights ( type:  Const )
# 180/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 181/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 182/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 183/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 184/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 185/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 186/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 187/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 188/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 189/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/weights ( type:  Const )
# 190/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 191/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/shortcut/biases ( type:  Const )
# 192/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/shortcut/biases/read ( type:  Identity )
# 193/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/shortcut/weights ( type:  Const )
# 194/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/shortcut/weights/read ( type:  Identity )
# 195/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/moving_variance ( type:  Const )
# 196/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 197/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/moving_mean ( type:  Const )
# 198/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 199/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/gamma ( type:  Const )
# 200/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 201/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/beta ( type:  Const )
# 202/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/beta/read ( type:  Identity )
# 203/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv3/biases ( type:  Const )
# 204/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 205/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv3/weights ( type:  Const )
# 206/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 207/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 208/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 209/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 210/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 211/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 212/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 213/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 214/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 215/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/weights ( type:  Const )
# 216/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 217/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 218/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 219/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 220/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 221/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 222/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 223/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 224/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 225/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/weights ( type:  Const )
# 226/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 227/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/moving_variance ( type:  Const )
# 228/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 229/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/moving_mean ( type:  Const )
# 230/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 231/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/gamma ( type:  Const )
# 232/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 233/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/beta ( type:  Const )
# 234/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/beta/read ( type:  Identity )
# 235/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv3/biases ( type:  Const )
# 236/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 237/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv3/weights ( type:  Const )
# 238/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 239/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 240/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 241/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 242/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 243/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 244/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 245/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 246/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 247/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/weights ( type:  Const )
# 248/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 249/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 250/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 251/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 252/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 253/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 254/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 255/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 256/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 257/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/weights ( type:  Const )
# 258/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 259/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/moving_variance ( type:  Const )
# 260/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 261/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/moving_mean ( type:  Const )
# 262/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 263/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/gamma ( type:  Const )
# 264/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 265/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/beta ( type:  Const )
# 266/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/beta/read ( type:  Identity )
# 267/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv3/biases ( type:  Const )
# 268/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 269/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv3/weights ( type:  Const )
# 270/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 271/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 272/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 273/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 274/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 275/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 276/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 277/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 278/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 279/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/weights ( type:  Const )
# 280/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 281/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 282/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 283/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 284/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 285/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 286/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 287/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 288/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 289/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/weights ( type:  Const )
# 290/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 291/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/moving_variance ( type:  Const )
# 292/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 293/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/moving_mean ( type:  Const )
# 294/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 295/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/gamma ( type:  Const )
# 296/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 297/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/beta ( type:  Const )
# 298/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/beta/read ( type:  Identity )
# 299/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv3/biases ( type:  Const )
# 300/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 301/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv3/weights ( type:  Const )
# 302/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 303/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 304/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 305/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 306/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 307/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 308/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 309/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 310/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 311/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/weights ( type:  Const )
# 312/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 313/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 314/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 315/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 316/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 317/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 318/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 319/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 320/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 321/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/weights ( type:  Const )
# 322/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 323/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/moving_variance ( type:  Const )
# 324/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 325/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/moving_mean ( type:  Const )
# 326/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 327/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/gamma ( type:  Const )
# 328/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 329/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/beta ( type:  Const )
# 330/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/beta/read ( type:  Identity )
# 331/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv3/biases ( type:  Const )
# 332/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 333/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv3/weights ( type:  Const )
# 334/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 335/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 336/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 337/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 338/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 339/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 340/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 341/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 342/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 343/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/weights ( type:  Const )
# 344/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 345/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 346/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 347/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 348/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 349/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 350/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 351/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 352/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 353/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/weights ( type:  Const )
# 354/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 355/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/moving_variance ( type:  Const )
# 356/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 357/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/moving_mean ( type:  Const )
# 358/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 359/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/gamma ( type:  Const )
# 360/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 361/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/beta ( type:  Const )
# 362/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/beta/read ( type:  Identity )
# 363/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv3/biases ( type:  Const )
# 364/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 365/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv3/weights ( type:  Const )
# 366/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 367/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 368/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 369/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 370/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 371/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 372/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 373/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 374/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 375/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/weights ( type:  Const )
# 376/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 377/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 378/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 379/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 380/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 381/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 382/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 383/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 384/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 385/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/weights ( type:  Const )
# 386/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 387/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/shortcut/biases ( type:  Const )
# 388/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/shortcut/biases/read ( type:  Identity )
# 389/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/shortcut/weights ( type:  Const )
# 390/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/shortcut/weights/read ( type:  Identity )
# 391/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/moving_variance ( type:  Const )
# 392/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 393/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/moving_mean ( type:  Const )
# 394/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 395/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/gamma ( type:  Const )
# 396/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 397/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/beta ( type:  Const )
# 398/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/beta/read ( type:  Identity )
# 399/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv3/biases ( type:  Const )
# 400/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 401/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv3/weights ( type:  Const )
# 402/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 403/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 404/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 405/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 406/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 407/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 408/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 409/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# 410/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/beta/read ( type:  Identity )
# 411/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/weights ( type:  Const )
# 412/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/weights/read ( type:  Identity )
# 413/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/Pad/paddings ( type:  Const )
# 414/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/moving_variance ( type:  Const )
# 415/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/moving_variance/read ( type:  Identity )
# 416/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/moving_mean ( type:  Const )
# 417/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/moving_mean/read ( type:  Identity )
# 418/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/gamma ( type:  Const )
# 419/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/gamma/read ( type:  Identity )
# 420/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/beta ( type:  Const )
# 421/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/beta/read ( type:  Identity )
# 422/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/weights ( type:  Const )
# 423/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/weights/read ( type:  Identity )
# 424/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/moving_variance ( type:  Const )
# 425/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/moving_variance/read ( type:  Identity )
# 426/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/moving_mean ( type:  Const )
# 427/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/moving_mean/read ( type:  Identity )
# 428/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/gamma ( type:  Const )
# 429/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/gamma/read ( type:  Identity )
# 430/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/beta ( type:  Const )
# 431/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/beta/read ( type:  Identity )
# 432/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv3/biases ( type:  Const )
# 433/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv3/biases/read ( type:  Identity )
# 434/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv3/weights ( type:  Const )
# 435/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv3/weights/read ( type:  Identity )
# 436/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv2/BatchNorm/moving_variance ( type:  Const )
# 437/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv2/BatchNorm/moving_variance/read ( type:  Identity )
# 438/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv2/BatchNorm/moving_mean ( type:  Const )
# 439/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv2/BatchNorm/moving_mean/read ( type:  Identity )
# 440/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv2/BatchNorm/gamma ( type:  Const )
# 441/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv2/BatchNorm/gamma/read ( type:  Identity )
# 442/870: Analysing op name: resnet_v2_50/block2/unit_3/bottleneck_v2/conv2/BatchNorm/beta ( type:  Const )
# ...
# 719/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/shortcut/MaxPool ( type:  MaxPool )
# 720/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 721/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/preact/Relu ( type:  Relu )
# 722/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 723/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 724/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv1/Relu ( type:  Relu )
# 725/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/Pad ( type:  Pad )
# 726/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 727/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 728/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv2/Relu ( type:  Relu )
# 729/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 730/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 731/870: Analysing op name: resnet_v2_50/block2/unit_4/bottleneck_v2/add ( type:  Add )
# 732/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 733/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/preact/Relu ( type:  Relu )
# 734/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 735/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 736/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv1/Relu ( type:  Relu )
# 737/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 738/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 739/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv2/Relu ( type:  Relu )
# 740/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 741/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 742/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/shortcut/Conv2D ( type:  Conv2D )
# 743/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/shortcut/BiasAdd ( type:  BiasAdd )
# 744/870: Analysing op name: resnet_v2_50/block3/unit_1/bottleneck_v2/add ( type:  Add )
# 745/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 746/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/preact/Relu ( type:  Relu )
# 747/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 748/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 749/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv1/Relu ( type:  Relu )
# 750/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 751/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 752/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv2/Relu ( type:  Relu )
# 753/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 754/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 755/870: Analysing op name: resnet_v2_50/block3/unit_2/bottleneck_v2/add ( type:  Add )
# 756/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 757/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/preact/Relu ( type:  Relu )
# 758/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 759/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 760/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv1/Relu ( type:  Relu )
# 761/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 762/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 763/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv2/Relu ( type:  Relu )
# 764/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 765/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 766/870: Analysing op name: resnet_v2_50/block3/unit_3/bottleneck_v2/add ( type:  Add )
# 767/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 768/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/preact/Relu ( type:  Relu )
# 769/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 770/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 771/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv1/Relu ( type:  Relu )
# 772/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 773/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 774/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv2/Relu ( type:  Relu )
# 775/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 776/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 777/870: Analysing op name: resnet_v2_50/block3/unit_4/bottleneck_v2/add ( type:  Add )
# 778/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 779/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/preact/Relu ( type:  Relu )
# 780/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 781/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 782/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv1/Relu ( type:  Relu )
# 783/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 784/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 785/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv2/Relu ( type:  Relu )
# 786/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 787/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 788/870: Analysing op name: resnet_v2_50/block3/unit_5/bottleneck_v2/add ( type:  Add )
# 789/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 790/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/preact/Relu ( type:  Relu )
# 791/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 792/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 793/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv1/Relu ( type:  Relu )
# 794/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 795/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 796/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv2/Relu ( type:  Relu )
# 797/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 798/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 799/870: Analysing op name: resnet_v2_50/block3/unit_6/bottleneck_v2/add ( type:  Add )
# 800/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 801/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/preact/Relu ( type:  Relu )
# 802/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 803/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 804/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv1/Relu ( type:  Relu )
# 805/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/SpaceToBatchND ( type:  SpaceToBatchND )
# 806/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 807/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchToSpaceND ( type:  BatchToSpaceND )
# 808/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 809/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv2/Relu ( type:  Relu )
# 810/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 811/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 812/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/shortcut/Conv2D ( type:  Conv2D )
# 813/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/shortcut/BiasAdd ( type:  BiasAdd )
# 814/870: Analysing op name: resnet_v2_50/block4/unit_1/bottleneck_v2/add ( type:  Add )
# 815/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 816/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/preact/Relu ( type:  Relu )
# 817/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 818/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 819/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv1/Relu ( type:  Relu )
# 820/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/SpaceToBatchND ( type:  SpaceToBatchND )
# 821/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 822/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchToSpaceND ( type:  BatchToSpaceND )
# 823/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 824/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv2/Relu ( type:  Relu )
# 825/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 826/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 827/870: Analysing op name: resnet_v2_50/block4/unit_2/bottleneck_v2/add ( type:  Add )
# 828/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/FusedBatchNorm ( type:  FusedBatchNorm )
# 829/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/preact/Relu ( type:  Relu )
# 830/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/Conv2D ( type:  Conv2D )
# 831/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 832/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv1/Relu ( type:  Relu )
# 833/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/SpaceToBatchND ( type:  SpaceToBatchND )
# 834/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/Conv2D ( type:  Conv2D )
# 835/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchToSpaceND ( type:  BatchToSpaceND )
# 836/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 837/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv2/Relu ( type:  Relu )
# 838/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv3/Conv2D ( type:  Conv2D )
# 839/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/conv3/BiasAdd ( type:  BiasAdd )
# 840/870: Analysing op name: resnet_v2_50/block4/unit_3/bottleneck_v2/add ( type:  Add )
# 841/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/SpaceToBatchND ( type:  SpaceToBatchND )
# 842/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/Conv2D ( type:  Conv2D )
# 843/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchToSpaceND ( type:  BatchToSpaceND )
# 844/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_3/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 845/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/SpaceToBatchND ( type:  SpaceToBatchND )
# 846/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/Conv2D ( type:  Conv2D )
# 847/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchToSpaceND ( type:  BatchToSpaceND )
# 848/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_2/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 849/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/SpaceToBatchND ( type:  SpaceToBatchND )
# 850/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/Conv2D ( type:  Conv2D )
# 851/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchToSpaceND ( type:  BatchToSpaceND )
# 852/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_3x3_1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 853/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/Conv2D ( type:  Conv2D )
# 854/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_0/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 855/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_global_pool ( type:  Mean )
# 856/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/Conv2D ( type:  Conv2D )
# 857/870: Analysing op name: DeepLab_v3/ASPP_layer/image_level_conv_1x1/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 858/870: Analysing op name: DeepLab_v3/ASPP_layer/Shape ( type:  Shape )
# 859/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice_1 ( type:  StridedSlice )
# 860/870: Analysing op name: DeepLab_v3/ASPP_layer/strided_slice ( type:  StridedSlice )
# 861/870: Analysing op name: DeepLab_v3/ASPP_layer/ResizeBilinear/size ( type:  Pack )
# 862/870: Analysing op name: DeepLab_v3/ASPP_layer/ResizeBilinear ( type:  ResizeBilinear )
# 863/870: Analysing op name: DeepLab_v3/ASPP_layer/concat ( type:  ConcatV2 )
# 864/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/Conv2D ( type:  Conv2D )
# 865/870: Analysing op name: DeepLab_v3/ASPP_layer/conv_1x1_output/BatchNorm/FusedBatchNorm ( type:  FusedBatchNorm )
# 866/870: Analysing op name: DeepLab_v3/logits/Conv2D ( type:  Conv2D )
# 867/870: Analysing op name: DeepLab_v3/logits/BiasAdd ( type:  BiasAdd )
# 868/870: Analysing op name: DeepLab_v3/ResizeBilinear ( type:  ResizeBilinear )
# 869/870: Analysing op name: strided_slice ( type:  StridedSlice )
# 870/870: Analysing op name: Softmax ( type:  Softmax )
# Translation to CoreML spec completed. Now compiling and saving the CoreML model.
#
#  Core ML model generated. Saved at location: model.mlmodel
#
# Core ML input(s):
#  [name: "Placeholder__0"
# type {
#   multiArrayType {
#     shape: 3
#     shape: 513
#     shape: 513
#     dataType: DOUBLE
#   }
# }
# ]
# Core ML output(s):
#  [name: "Softmax__0"
# type {
#   multiArrayType {
#     dataType: DOUBLE
#   }
# }
# ]

# %%
coreml_model
# Out:
# input {
#   name: "Placeholder__0"
#   type {
#     multiArrayType {
#       shape: 3
#       shape: 513
#       shape: 513
#       dataType: DOUBLE
#     }
#   }
# }
# output {
#   name: "Softmax__0"
#   type {
#     multiArrayType {
#       dataType: DOUBLE
#     }
#   }
# }

# %% [markdown]
# #### Let's test it!

# %%
"""
Step 3: Run the converted model
"""

# Provide CoreML model with a dictionary as input. Change ':0' to '__0'
# as Swift / Objective-C code generation do not allow colons in variable names
np.random.seed(100)
coreml_inputs = {'Placeholder__0': np.moveaxis(jpeg_bin[0], 2, 0)} # (sequence_length=1,batch=1,channels=784)
coreml_output = coreml_model.predict(coreml_inputs, useCPUOnly=True)

# %%
coreml_output['Softmax__0'][0][0][15]
# Out:
# array([[8.69663927e-06, 8.75525620e-06, 8.81426968e-06, ...,
#         5.59820421e-07, 5.59820421e-07, 5.59820421e-07],
#        [1.05779181e-05, 1.06630832e-05, 1.07488877e-05, ...,
#         5.71514192e-07, 5.71514192e-07, 5.71514192e-07],
#        [1.28661422e-05, 1.29865730e-05, 1.31081497e-05, ...,
#         5.83452163e-07, 5.83452163e-07, 5.83452163e-07],
#        ...,
#        [2.05195183e-03, 1.71889353e-03, 1.43965404e-03, ...,
#         1.20850040e-04, 1.20850040e-04, 1.20850040e-04],
#        [2.05195183e-03, 1.71889353e-03, 1.43965404e-03, ...,
#         1.20850040e-04, 1.20850040e-04, 1.20850040e-04],
#        [2.05195183e-03, 1.71889353e-03, 1.43965404e-03, ...,
#         1.20850040e-04, 1.20850040e-04, 1.20850040e-04]])

# %%
plt.imshow(coreml_output['Softmax__0'][0][0][15], )

# %%
import cv2

resized_output = cv2.resize(np.array(coreml_output['Softmax__0'][0][0][15]), dsize=(768, 960), )

# %% [markdown]
# #### Yeah, we get it!

# %%
plt.imshow(resized_output)

# %%
input_img = cv2.imread('test_image//4.jpg')

# %%
resized_output[:, :, None][resized_output[:, :, None] > 0.5] = 1.0
resized_output[:, :, None][resized_output[:, :, None] <= 0.5] = 0.0

# %%
def show_images(input_image, input_title, output_image, output_title, cmap=None):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 35))
    
    ax1.imshow(input_image, cmap=cmap)
    ax1.set_title(input_title)
    
    ax2.imshow(output_image, cmap=cmap)
    ax2.set_title(output_title)

# %%
show_images(cv2.cvtColor(np.array(input_img, dtype=np.uint8), cv2.COLOR_BGR2RGB), "Input image", 
            cv2.cvtColor(np.array(result_mask, dtype=np.uint8), cv2.COLOR_BGR2RGB), "Masked image", cmap=None)
